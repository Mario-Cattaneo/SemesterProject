# %% [markdown]
# <a href="https://colab.research.google.com/github/Mario-Cattaneo/SemesterProject/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
print("CUDA Available:", torch.cuda.is_available())
print("Device Count:", torch.cuda.device_count())
if torch.cuda.is_available():
    print("Current GPU:", torch.cuda.get_device_name(0))
# Out:
# CUDA Available: True
# Device Count: 1
# Current GPU: Tesla T4

# %%
# =========================================================================
# CELL: Mount Google Drive and Setup Save Directory
# =========================================================================
import os
import json

try:
    from google.colab import drive
    drive.mount('/content/drive')
    SAVE_DIR = "/content/drive/MyDrive/MIB_Collaborative_Inference_Results"
except Exception as e:
    print("--> Running outside Google Colab. Saving to local './results' directory.")
    SAVE_DIR = "./results"

os.makedirs(SAVE_DIR, exist_ok=True)
print(f"--> All plots and numerical data will be saved to: {SAVE_DIR}")
# Out:
# --> Running outside Google Colab. Saving to local './results' directory.
# --> All plots and numerical data will be saved to: ./results

# %%
# =========================================================================
# CELL 1: Backbones (Split-ResNet and Tiny-ViT for Diamond Graph)
# =========================================================================
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import numpy as np
import matplotlib.pyplot as plt
import copy

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# -------------------------------------------------------------------------
# 1. Split-ResNet (1-channel MNIST/Fashion-MNIST)
# -------------------------------------------------------------------------
class BasicBlock(nn.Module):
    def __init__(self, in_planes, planes, stride=1):
        super().__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        return F.relu(out)

class ResNetSource(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv = nn.Conv2d(1, 32, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn = nn.BatchNorm2d(32)
        self.layer1 = BasicBlock(32, 32)
    def forward(self, x):
        # Outputs [B, 32, 28, 28] -> Split 16 channels to Worker 1, 16 to Worker 2
        return self.layer1(F.relu(self.bn(self.conv(x))))

class ResNetWorker(nn.Module):
    def __init__(self):
        super().__init__()
        self.layer2 = BasicBlock(16, 32, stride=2) # [B, 32, 14, 14]
        self.pool = nn.AdaptiveAvgPool2d((1, 1))   # [B, 32]
    def forward(self, x):
        return torch.flatten(self.pool(self.layer2(x)), 1)

class ResNetSink(nn.Module):
    def __init__(self, in_dim=64, num_classes=10):
        super().__init__()
        self.classifier = nn.Linear(in_dim, num_classes)
    def forward(self, x):
        return self.classifier(x)

# -------------------------------------------------------------------------
# 2. Tiny-ViT (Patch size 4x4, Embedding 64)
# -------------------------------------------------------------------------
class ViTSource(nn.Module):
    def __init__(self, patch_size=4, emb_dim=64):
        super().__init__()
        self.proj = nn.Conv2d(1, emb_dim, kernel_size=patch_size, stride=patch_size)
        self.pos_embed = nn.Parameter(torch.zeros(1, 49, emb_dim))
        layer = nn.TransformerEncoderLayer(d_model=emb_dim, nhead=4, dim_feedforward=128, batch_first=True)
        self.block = nn.TransformerEncoder(layer, num_layers=1)
    def forward(self, x):
        x = self.proj(x).flatten(2).transpose(1, 2) + self.pos_embed
        return self.block(x) # [B, 49, 64]

class ViTWorker(nn.Module):
    def __init__(self, emb_dim=64):
        super().__init__()
        layer = nn.TransformerEncoderLayer(d_model=emb_dim, nhead=4, dim_feedforward=128, batch_first=True)
        self.block = nn.TransformerEncoder(layer, num_layers=1)
    def forward(self, x):
        # Return pooled token representation [B, 64]
        return self.block(x).mean(dim=1)

class ViTSink(nn.Module):
    def __init__(self, in_dim=128, num_classes=10):
        super().__init__()
        self.classifier = nn.Linear(in_dim, num_classes)
    def forward(self, x):
        return self.classifier(x)

print("--> Backbone splits defined.")
# Out:
# --> Backbone splits defined.

# %%
# =========================================================================
# CELL 2: Codecs and Mutual Information Rate Bounds
# =========================================================================

class VariationalEncoder(nn.Module):
    def __init__(self, in_dim, bottleneck_dim):
        super().__init__()
        self.fc_mu = nn.Linear(in_dim, bottleneck_dim)
        self.fc_logvar = nn.Linear(in_dim, bottleneck_dim)

    def forward(self, z):
        mu = self.fc_mu(z)
        logvar = torch.clamp(self.fc_logvar(z), min=-5.0, max=5.0)
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        u = mu + eps * std
        return u, mu, logvar, eps

class PhysicalChannel(nn.Module):
    def __init__(self, snr_db=10.0):
        super().__init__()
        self.snr_db = snr_db
    def forward(self, u):
        norm = torch.norm(u, p=2, dim=-1, keepdim=True) + 1e-8
        u_norm = u / norm
        snr_lin = 10.0 ** (self.snr_db / 10.0)
        noise = torch.randn_like(u_norm) * np.sqrt(1.0 / (2.0 * snr_lin))
        return (u_norm + noise) * norm

def compute_rate_vub(mu, logvar):
    kl = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp(), dim=-1)
    return torch.mean(kl)

def compute_rate_club(u, mu, logvar, eps):
    std = torch.exp(0.5 * logvar)
    pos_term = eps.pow(2).sum(dim=-1)
    u_neg = torch.roll(u, shifts=1, dims=0)
    neg_term = (((u_neg - mu) / std).pow(2)).sum(dim=-1)
    return 0.5 * torch.mean(neg_term - pos_term)

print("--> Codecs and Loss modules initialized.")
# Out:
# --> Codecs and Loss modules initialized.

# %%
# =========================================================================
# CELL 3: Diamond Model Supporting All 4 MIB Objectives
# =========================================================================

class UnifiedDiamondModel(nn.Module):
    def __init__(self, backbone_type="resnet", bottleneck_dim=16, snr_db=10.0):
        super().__init__()
        self.backbone_type = backbone_type
        self.bottleneck_dim = bottleneck_dim

        if backbone_type == "resnet":
            self.source = ResNetSource()
            self.worker1 = ResNetWorker()
            self.worker2 = ResNetWorker()
            self.worker_dim = 32
        elif backbone_type == "vit":
            self.source = ViTSource()
            self.worker1 = ViTWorker()
            self.worker2 = ViTWorker()
            self.worker_dim = 64

        # Encoders & Channel
        self.enc_w1 = VariationalEncoder(self.worker_dim, bottleneck_dim)
        self.enc_w2 = VariationalEncoder(self.worker_dim, bottleneck_dim)
        self.channel = PhysicalChannel(snr_db=snr_db)

        # 1. Heads for JG: Joint classifier on [u1, u2]
        self.sink_jg = nn.Linear(2 * bottleneck_dim, 10)

        # 2. Heads for SG: Individual classifiers on u1 and u2
        self.head_sg1 = nn.Linear(bottleneck_dim, 10)
        self.head_sg2 = nn.Linear(bottleneck_dim, 10)

        # 3. Decoders for SL: Separate reconstruction of z_w1 and z_w2
        self.dec_sl1 = nn.Sequential(nn.Linear(bottleneck_dim, self.worker_dim), nn.ReLU(), nn.Linear(self.worker_dim, self.worker_dim))
        self.dec_sl2 = nn.Sequential(nn.Linear(bottleneck_dim, self.worker_dim), nn.ReLU(), nn.Linear(self.worker_dim, self.worker_dim))

        # 4. Decoder for JL: Joint reconstruction of [z_w1, z_w2]
        self.dec_jl = nn.Sequential(nn.Linear(2 * bottleneck_dim, 2 * self.worker_dim), nn.ReLU(), nn.Linear(2 * self.worker_dim, 2 * self.worker_dim))

        # Pretrained sink head for evaluating SL and JL reconstructions
        self.sink_pretrained = nn.Linear(2 * self.worker_dim, 10)

    def extract_workers(self, x):
        """Extract intermediate features z_w1, z_w2"""
        if self.backbone_type == "resnet":
            z_s = self.source(x)
            z_w1 = self.worker1(z_s[:, :16])
            z_w2 = self.worker2(z_s[:, 16:])
        else:
            z_s = self.source(x)
            z_w1 = self.worker1(z_s[:, :25])
            z_w2 = self.worker2(z_s[:, 25:])
        return z_w1, z_w2

    def forward_from_z(self, z_w1, z_w2):
        """Forward pass from intermediate tensors (enables instant cached training)"""
        u1, mu1, logvar1, eps1 = self.enc_w1(z_w1)
        u2, mu2, logvar2, eps2 = self.enc_w2(z_w2)

        u_bar1 = self.channel(u1)
        u_bar2 = self.channel(u2)
        r_t = torch.cat([u_bar1, u_bar2], dim=-1)

        # 1. Predictions for JG
        y_hat_jg = self.sink_jg(r_t)

        # 2. Predictions for SG
        y_hat_sg = 0.5 * (self.head_sg1(u_bar1) + self.head_sg2(u_bar2))

        # 3. Reconstructions for SL
        z_recon_sl1 = self.dec_sl1(u_bar1)
        z_recon_sl2 = self.dec_sl2(u_bar2)
        y_hat_sl = self.sink_pretrained(torch.cat([z_recon_sl1, z_recon_sl2], dim=-1))

        # 4. Reconstructions for JL
        z_recon_jl = self.dec_jl(r_t)
        y_hat_jl = self.sink_pretrained(z_recon_jl)

        edge_data = {
            "w1": {"z": z_w1, "u": u1, "mu": mu1, "logvar": logvar1, "eps": eps1, "z_recon_sl": z_recon_sl1},
            "w2": {"z": z_w2, "u": u2, "mu": mu2, "logvar": logvar2, "eps": eps2, "z_recon_sl": z_recon_sl2},
            "jl": {"z_true": torch.cat([z_w1, z_w2], dim=-1), "z_recon": z_recon_jl}
        }
        preds = {"JG": y_hat_jg, "SG": y_hat_sg, "JL": y_hat_jl, "SL": y_hat_sl}
        return preds, edge_data

    def forward(self, x):
        z_w1, z_w2 = self.extract_workers(x)
        return self.forward_from_z(z_w1, z_w2)

print("--> Diamond Pipeline with all 4 objectives initialized.")
# Out:
# --> Diamond Pipeline with all 4 objectives initialized.

# %%
# =========================================================================
# CELL 4: Streamlined Training Engine (Jointly & Separately Only)
# =========================================================================

def pretrain_backbone_fast(backbone_type="resnet", epochs=2):
    print(f"\n[Pretraining Step] Initializing {backbone_type.upper()} backbone (Epochs={epochs})...")
    model = UnifiedDiamondModel(backbone_type=backbone_type, bottleneck_dim=32, snr_db=30.0).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=1.5e-3)
    scaler = torch.amp.GradScaler(device.type, enabled=(device.type == 'cuda'))

    for epoch in range(1, epochs + 1):
        model.train()
        for x, y in train_loader:
            x, y = x.to(device, non_blocking=True), y.to(device, non_blocking=True)
            optimizer.zero_grad()
            with torch.amp.autocast(device_type=device.type, enabled=(device.type == 'cuda')):
                z_w1, z_w2 = model.extract_workers(x)
                y_hat = model.sink_pretrained(torch.cat([z_w1, z_w2], dim=-1))
                loss = F.cross_entropy(y_hat, y)
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()
        print(f"  --> {backbone_type.upper()} Baseline Epoch {epoch}/{epochs} finished.")

    # Cache intermediate features for "Separately" mode
    print(f"  --> Pre-extracting and caching {backbone_type.upper()} intermediate worker features...")
    model.eval()
    cached_train, cached_test = [], []
    with torch.no_grad():
        for x, y in train_loader:
            x, y = x.to(device), y.to(device)
            z1, z2 = model.extract_workers(x)
            cached_train.append((z1.cpu(), z2.cpu(), y.cpu()))
        for x, y in test_loader:
            x, y = x.to(device), y.to(device)
            z1, z2 = model.extract_workers(x)
            cached_test.append((z1.cpu(), z2.cpu(), y.cpu()))

    print(f"  --> {backbone_type.upper()} Caching complete.")
    return model.state_dict(), cached_train, cached_test

def train_and_eval_fast(
    model, pretrained_state, cached_data, training_style,
    rel_type="JG", rate_type="CLUB", epochs=2, lam=1e-3
):
    model = model.to(device)
    scaler = torch.amp.GradScaler(device.type, enabled=(device.type == 'cuda'))

    # Load sink classifier for evaluating local reconstructions (JL / SL)
    sink_pretrained_weights = {
        k.replace("sink_pretrained.", ""): v
        for k, v in pretrained_state.items()
        if "sink_pretrained." in k
    }
    model.sink_pretrained.load_state_dict(sink_pretrained_weights)

    # ---------------------------------------------------------------------
    # 1. TWO-STAGE (SEPARATELY) MODE: Ultra-fast on cached tensors
    # ---------------------------------------------------------------------
    if training_style == "separately":
        train_cache, test_cache = cached_data
        optimizer = torch.optim.Adam(model.parameters(), lr=2e-3)

        for epoch in range(epochs):
            model.train()
            for z1, z2, y in train_cache:
                z1, z2, y = z1.to(device), z2.to(device), y.to(device)
                optimizer.zero_grad()
                with torch.amp.autocast(device_type=device.type, enabled=(device.type == 'cuda')):
                    preds, edge_data = model.forward_from_z(z1, z2)

                    if rel_type == "JG":
                        loss_rel = F.cross_entropy(preds["JG"], y)
                    elif rel_type == "SG":
                        loss_rel = 0.5 * (F.cross_entropy(model.head_sg1(edge_data["w1"]["u"]), y) +
                                          F.cross_entropy(model.head_sg2(edge_data["w2"]["u"]), y))
                    elif rel_type == "SL":
                        loss_rel = F.mse_loss(edge_data["w1"]["z_recon_sl"], z1) + \
                                   F.mse_loss(edge_data["w2"]["z_recon_sl"], z2)
                    elif rel_type == "JL":
                        loss_rel = F.mse_loss(edge_data["jl"]["z_recon"], edge_data["jl"]["z_true"])

                    loss_rate = 0.0
                    for k in ["w1", "w2"]:
                        if rate_type == "VUB":
                            loss_rate += compute_rate_vub(edge_data[k]["mu"], edge_data[k]["logvar"])
                        else:
                            loss_rate += compute_rate_club(edge_data[k]["u"], edge_data[k]["mu"], edge_data[k]["logvar"], edge_data[k]["eps"])

                    total_loss = loss_rel + lam * loss_rate

                scaler.scale(total_loss).backward()
                scaler.step(optimizer)
                scaler.update()

        model.eval()
        correct, total = 0, 0
        with torch.no_grad():
            for z1, z2, y in test_cache:
                z1, z2, y = z1.to(device), z2.to(device), y.to(device)
                preds, _ = model.forward_from_z(z1, z2)
                correct += (torch.argmax(preds[rel_type], dim=-1) == y).sum().item()
                total += y.size(0)
        return 100.0 * correct / total

    # ---------------------------------------------------------------------
    # 2. JOINTLY MODE (JG and SG only)
    # ---------------------------------------------------------------------
    else:
        optimizer = torch.optim.Adam(model.parameters(), lr=1.5e-3)

        for epoch in range(epochs):
            model.train()
            for x, y in train_loader:
                x, y = x.to(device, non_blocking=True), y.to(device, non_blocking=True)
                optimizer.zero_grad()
                with torch.amp.autocast(device_type=device.type, enabled=(device.type == 'cuda')):
                    preds, edge_data = model(x)

                    if rel_type == "JG":
                        loss_rel = F.cross_entropy(preds["JG"], y)
                    elif rel_type == "SG":
                        loss_rel = 0.5 * (F.cross_entropy(model.head_sg1(edge_data["w1"]["u"]), y) +
                                          F.cross_entropy(model.head_sg2(edge_data["w2"]["u"]), y))
                    else:
                        raise ValueError("Local objectives are excluded from joint training.")

                    loss_rate = 0.0
                    for k in ["w1", "w2"]:
                        if rate_type == "VUB":
                            loss_rate += compute_rate_vub(edge_data[k]["mu"], edge_data[k]["logvar"])
                        else:
                            loss_rate += compute_rate_club(edge_data[k]["u"], edge_data[k]["mu"], edge_data[k]["logvar"], edge_data[k]["eps"])

                    total_loss = loss_rel + lam * loss_rate

                scaler.scale(total_loss).backward()
                scaler.step(optimizer)
                scaler.update()

        model.eval()
        correct, total = 0, 0
        with torch.no_grad():
            for x, y in test_loader:
                x, y = x.to(device), y.to(device)
                preds, _ = model(x)
                correct += (torch.argmax(preds[rel_type], dim=-1) == y).sum().item()
                total += y.size(0)
        return 100.0 * correct / total

print("--> Streamlined training engine initialized.")
# Out:
# --> Streamlined training engine initialized.

# %%
# =========================================================================
# CELL 5: Full Sweep (2x2 Grid, Cleaned Objectives, Drive Auto-Save)
# =========================================================================
import time

# 1. DataLoader
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])
train_loader = DataLoader(datasets.MNIST(root="./data", train=True, download=True, transform=transform), batch_size=256, shuffle=True, pin_memory=(device.type == 'cuda'))
test_loader = DataLoader(datasets.MNIST(root="./data", train=False, download=True, transform=transform), batch_size=256, shuffle=False, pin_memory=(device.type == 'cuda'))

# 2. Pretrain each backbone once
state_resnet, cache_tr_res, cache_te_res = pretrain_backbone_fast("resnet", epochs=2)
state_vit, cache_tr_vit, cache_te_vit = pretrain_backbone_fast("vit", epochs=2)

pretrained_meta = {
    "resnet": (state_resnet, (cache_tr_res, cache_te_res)),
    "vit": (state_vit, (cache_tr_vit, cache_te_vit))
}

# 3. Swept Rate Points
rate_points = [4, 8, 12, 16, 24, 32]

# 4. Styling Definitions
color_map = {"CLUB": "crimson", "VUB": "navy"}
line_map = {"CLUB": "-", "VUB": "--"}
marker_map = {"JG": "o", "SG": "s", "JL": "^", "SL": "v"}

bounds = ["CLUB", "VUB"]
models = ["resnet", "vit"]
styles = ["jointly", "separately"]

# Calculate total runs:
# Jointly: 2 models * 2 objectives (JG, SG) * 2 bounds * 6 rates = 48 runs
# Separately: 2 models * 4 objectives (JG, SG, JL, SL) * 2 bounds * 6 rates = 96 runs
total_evaluations = (2 * 2 * 2 * len(rate_points)) + (2 * 4 * 2 * len(rate_points))
eval_counter = 0
overall_start_time = time.time()

raw_metrics_log = {}

# 2x2 Subplot Layout
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 11), sharex=True)

print(f"\n{'='*80}")
print(f"--> STARTING OPTIMIZED BENCHMARK SWEEP (Total runs: {total_evaluations})")
print(f"{'='*80}")

for r_idx, m_name in enumerate(models):
    state, cache = pretrained_meta[m_name]
    raw_metrics_log[m_name] = {}

    for c_idx, s_name in enumerate(styles):
        ax = axes[r_idx, c_idx]
        raw_metrics_log[m_name][s_name] = {}

        # Jointly: JG and SG only | Separately: all 4 objectives
        active_objectives = ["JG", "SG"] if s_name == "jointly" else ["JG", "SG", "JL", "SL"]

        for obj in active_objectives:
            for bnd in bounds:
                acc_curve = []
                series_key = f"{obj}_{bnd}"

                for K in rate_points:
                    eval_counter += 1
                    t0 = time.time()

                    model = UnifiedDiamondModel(backbone_type=m_name, bottleneck_dim=K, snr_db=10.0)
                    acc = train_and_eval_fast(
                        model, state, cache, training_style=s_name,
                        rel_type=obj, rate_type=bnd, epochs=2, lam=1e-3
                    )
                    acc_curve.append(acc)
                    dt = time.time() - t0

                    progress_pct = (eval_counter / total_evaluations) * 100.0
                    print(f"[{eval_counter:3d}/{total_evaluations} | {progress_pct:5.1f}%] "
                          f"{m_name.upper():6s} | {s_name:10s} | {obj:2s}-{bnd:4s} | "
                          f"K={K:2d} --> Acc: {acc:6.2f}% | Step Time: {dt:4.1f}s")

                raw_metrics_log[m_name][s_name][series_key] = acc_curve

                # Plot curve
                ax.plot(
                    rate_points, acc_curve,
                    color=color_map[bnd],
                    marker=marker_map[obj],
                    linestyle=line_map[bnd],
                    linewidth=1.8,
                    markersize=6,
                    label=f"{obj}-{bnd}"
                )

        ax.set_title(f"{m_name.upper()} ({s_name.capitalize()})", fontsize=12, fontweight="bold")
        ax.set_xticks(rate_points)
        ax.grid(True, linestyle=":", alpha=0.6)
        if c_idx == 0:
            ax.set_ylabel("Target Accuracy (%)", fontsize=11)
        if r_idx == 1:
            ax.set_xlabel("Channel Rate (Bottleneck Dim $K$)", fontsize=11)
        ax.legend(fontsize=9, loc="lower right")

plt.suptitle("Rate-Accuracy Trade-off Across Backbones and Training Schemes (Diamond Topology)", fontsize=14, y=0.98)
plt.tight_layout()

# =========================================================================
# SAVE TO GOOGLE DRIVE
# =========================================================================
png_path = os.path.join(SAVE_DIR, "rate_accuracy_clean_2x2.png")
pdf_path = os.path.join(SAVE_DIR, "rate_accuracy_clean_2x2.pdf")
json_path = os.path.join(SAVE_DIR, "benchmark_clean_metrics.json")

print(f"\n--> Saving figures and metrics to: {SAVE_DIR}")
plt.savefig(png_path, dpi=300, bbox_inches='tight')
plt.savefig(pdf_path, bbox_inches='tight')

with open(json_path, 'w') as f:
    json.dump(raw_metrics_log, f, indent=4)

total_mins = (time.time() - overall_start_time) / 60.0
print(f"--> Done! Full benchmark finished in {total_mins:.1f} minutes.")
print(f"    - PNG:  {png_path}")
print(f"    - PDF:  {pdf_path}")
print(f"    - JSON: {json_path}")

plt.show()
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 18.2MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 498kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.64MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 16.1MB/s]
# [Pretraining Step] Initializing RESNET backbone (Epochs=2)...
#   --> RESNET Baseline Epoch 1/2 finished.
#   --> RESNET Baseline Epoch 2/2 finished.
#   --> Pre-extracting and caching RESNET intermediate worker features...
#   --> RESNET Caching complete.
#
# [Pretraining Step] Initializing VIT backbone (Epochs=2)...
#   --> VIT Baseline Epoch 1/2 finished.
#   --> VIT Baseline Epoch 2/2 finished.
#   --> Pre-extracting and caching VIT intermediate worker features...
#   --> VIT Caching complete.
#
# ================================================================================
# --> STARTING OPTIMIZED BENCHMARK SWEEP (Total runs: 144)
# ================================================================================
# [  1/144 |   0.7%] RESNET | jointly    | JG-CLUB | K= 4 --> Acc:  87.53% | Step Time: 37.6s
# [  2/144 |   1.4%] RESNET | jointly    | JG-CLUB | K= 8 --> Acc:  82.34% | Step Time: 37.5s
# [  3/144 |   2.1%] RESNET | jointly    | JG-CLUB | K=12 --> Acc:  81.73% | Step Time: 37.1s
# [  4/144 |   2.8%] RESNET | jointly    | JG-CLUB | K=16 --> Acc:  89.45% | Step Time: 37.0s
# [  5/144 |   3.5%] RESNET | jointly    | JG-CLUB | K=24 --> Acc:  92.16% | Step Time: 36.8s
# [  6/144 |   4.2%] RESNET | jointly    | JG-CLUB | K=32 --> Acc:  89.57% | Step Time: 36.2s
# [  7/144 |   4.9%] RESNET | jointly    | JG-VUB  | K= 4 --> Acc:  85.86% | Step Time: 35.6s
# [  8/144 |   5.6%] RESNET | jointly    | JG-VUB  | K= 8 --> Acc:  93.79% | Step Time: 35.5s
# [  9/144 |   6.2%] RESNET | jointly    | JG-VUB  | K=12 --> Acc:  90.99% | Step Time: 36.0s
# [ 10/144 |   6.9%] RESNET | jointly    | JG-VUB  | K=16 --> Acc:  89.23% | Step Time: 36.0s
# [ 11/144 |   7.6%] RESNET | jointly    | JG-VUB  | K=24 --> Acc:  93.90% | Step Time: 35.7s
# [ 12/144 |   8.3%] RESNET | jointly    | JG-VUB  | K=32 --> Acc:  91.32% | Step Time: 35.6s
# [ 13/144 |   9.0%] RESNET | jointly    | SG-CLUB | K= 4 --> Acc:  89.58% | Step Time: 35.7s
# [ 14/144 |   9.7%] RESNET | jointly    | SG-CLUB | K= 8 --> Acc:  82.94% | Step Time: 35.4s
# [ 15/144 |  10.4%] RESNET | jointly    | SG-CLUB | K=12 --> Acc:  87.28% | Step Time: 36.4s
# [ 16/144 |  11.1%] RESNET | jointly    | SG-CLUB | K=16 --> Acc:  83.84% | Step Time: 36.4s
# [ 17/144 |  11.8%] RESNET | jointly    | SG-CLUB | K=24 --> Acc:  72.14% | Step Time: 36.5s
# [ 18/144 |  12.5%] RESNET | jointly    | SG-CLUB | K=32 --> Acc:  83.22% | Step Time: 36.6s
# [ 19/144 |  13.2%] RESNET | jointly    | SG-VUB  | K= 4 --> Acc:  86.44% | Step Time: 36.5s
# [ 20/144 |  13.9%] RESNET | jointly    | SG-VUB  | K= 8 --> Acc:  90.56% | Step Time: 36.5s
# [ 21/144 |  14.6%] RESNET | jointly    | SG-VUB  | K=12 --> Acc:  92.74% | Step Time: 36.3s
# [ 22/144 |  15.3%] RESNET | jointly    | SG-VUB  | K=16 --> Acc:  92.37% | Step Time: 36.3s
# [ 23/144 |  16.0%] RESNET | jointly    | SG-VUB  | K=24 --> Acc:  86.71% | Step Time: 35.8s
# [ 24/144 |  16.7%] RESNET | jointly    | SG-VUB  | K=32 --> Acc:  89.06% | Step Time: 36.0s
# [ 25/144 |  17.4%] RESNET | separately | JG-CLUB | K= 4 --> Acc:  92.79% | Step Time:  3.5s
# [ 26/144 |  18.1%] RESNET | separately | JG-CLUB | K= 8 --> Acc:  93.29% | Step Time:  2.8s
# [ 27/144 |  18.8%] RESNET | separately | JG-CLUB | K=12 --> Acc:  92.78% | Step Time:  2.9s
# [ 28/144 |  19.4%] RESNET | separately | JG-CLUB | K=16 --> Acc:  92.90% | Step Time:  2.9s
# [ 29/144 |  20.1%] RESNET | separately | JG-CLUB | K=24 --> Acc:  92.82% | Step Time:  3.4s
# [ 30/144 |  20.8%] RESNET | separately | JG-CLUB | K=32 --> Acc:  92.59% | Step Time:  2.9s
# [ 31/144 |  21.5%] RESNET | separately | JG-VUB  | K= 4 --> Acc:  95.16% | Step Time:  2.8s
# [ 32/144 |  22.2%] RESNET | separately | JG-VUB  | K= 8 --> Acc:  95.35% | Step Time:  2.8s
# [ 33/144 |  22.9%] RESNET | separately | JG-VUB  | K=12 --> Acc:  95.28% | Step Time:  3.1s
# [ 34/144 |  23.6%] RESNET | separately | JG-VUB  | K=16 --> Acc:  95.57% | Step Time:  3.2s
# [ 35/144 |  24.3%] RESNET | separately | JG-VUB  | K=24 --> Acc:  95.51% | Step Time:  2.9s
# [ 36/144 |  25.0%] RESNET | separately | JG-VUB  | K=32 --> Acc:  95.07% | Step Time:  2.8s
# [ 37/144 |  25.7%] RESNET | separately | SG-CLUB | K= 4 --> Acc:  90.55% | Step Time:  3.1s
# [ 38/144 |  26.4%] RESNET | separately | SG-CLUB | K= 8 --> Acc:  90.43% | Step Time:  3.3s
# [ 39/144 |  27.1%] RESNET | separately | SG-CLUB | K=12 --> Acc:  89.64% | Step Time:  2.9s
# [ 40/144 |  27.8%] RESNET | separately | SG-CLUB | K=16 --> Acc:  88.58% | Step Time:  2.9s
# [ 41/144 |  28.5%] RESNET | separately | SG-CLUB | K=24 --> Acc:  87.50% | Step Time:  3.1s
# [ 42/144 |  29.2%] RESNET | separately | SG-CLUB | K=32 --> Acc:  87.41% | Step Time:  3.4s
# [ 43/144 |  29.9%] RESNET | separately | SG-VUB  | K= 4 --> Acc:  93.50% | Step Time:  2.8s
# [ 44/144 |  30.6%] RESNET | separately | SG-VUB  | K= 8 --> Acc:  93.70% | Step Time:  2.8s
# [ 45/144 |  31.2%] RESNET | separately | SG-VUB  | K=12 --> Acc:  92.95% | Step Time:  2.9s
# [ 46/144 |  31.9%] RESNET | separately | SG-VUB  | K=16 --> Acc:  93.14% | Step Time:  3.4s
# [ 47/144 |  32.6%] RESNET | separately | SG-VUB  | K=24 --> Acc:  93.14% | Step Time:  2.9s
# [ 48/144 |  33.3%] RESNET | separately | SG-VUB  | K=32 --> Acc:  92.91% | Step Time:  2.8s
# [ 49/144 |  34.0%] RESNET | separately | JL-CLUB | K= 4 --> Acc:  81.84% | Step Time:  3.2s
# [ 50/144 |  34.7%] RESNET | separately | JL-CLUB | K= 8 --> Acc:  81.41% | Step Time:  3.6s
# [ 51/144 |  35.4%] RESNET | separately | JL-CLUB | K=12 --> Acc:  81.35% | Step Time:  3.1s
# [ 52/144 |  36.1%] RESNET | separately | JL-CLUB | K=16 --> Acc:  81.60% | Step Time:  2.9s
# [ 53/144 |  36.8%] RESNET | separately | JL-CLUB | K=24 --> Acc:  80.30% | Step Time:  3.0s
# [ 54/144 |  37.5%] RESNET | separately | JL-CLUB | K=32 --> Acc:  78.79% | Step Time:  3.6s
# [ 55/144 |  38.2%] RESNET | separately | JL-VUB  | K= 4 --> Acc:  90.48% | Step Time:  2.9s
# [ 56/144 |  38.9%] RESNET | separately | JL-VUB  | K= 8 --> Acc:  90.60% | Step Time:  2.8s
# [ 57/144 |  39.6%] RESNET | separately | JL-VUB  | K=12 --> Acc:  88.39% | Step Time:  2.8s
# [ 58/144 |  40.3%] RESNET | separately | JL-VUB  | K=16 --> Acc:  88.65% | Step Time:  3.5s
# [ 59/144 |  41.0%] RESNET | separately | JL-VUB  | K=24 --> Acc:  88.53% | Step Time:  2.9s
# [ 60/144 |  41.7%] RESNET | separately | JL-VUB  | K=32 --> Acc:  85.71% | Step Time:  2.9s
# [ 61/144 |  42.4%] RESNET | separately | SL-CLUB | K= 4 --> Acc:  77.88% | Step Time:  3.2s
# [ 62/144 |  43.1%] RESNET | separately | SL-CLUB | K= 8 --> Acc:  79.12% | Step Time:  3.8s
# [ 63/144 |  43.8%] RESNET | separately | SL-CLUB | K=12 --> Acc:  81.28% | Step Time:  3.1s
# [ 64/144 |  44.4%] RESNET | separately | SL-CLUB | K=16 --> Acc:  80.26% | Step Time:  3.2s
# [ 65/144 |  45.1%] RESNET | separately | SL-CLUB | K=24 --> Acc:  79.86% | Step Time:  3.3s
# [ 66/144 |  45.8%] RESNET | separately | SL-CLUB | K=32 --> Acc:  77.99% | Step Time:  3.6s
# [ 67/144 |  46.5%] RESNET | separately | SL-VUB  | K= 4 --> Acc:  87.99% | Step Time:  3.1s
# [ 68/144 |  47.2%] RESNET | separately | SL-VUB  | K= 8 --> Acc:  88.34% | Step Time:  3.1s
# [ 69/144 |  47.9%] RESNET | separately | SL-VUB  | K=12 --> Acc:  89.44% | Step Time:  3.4s
# [ 70/144 |  48.6%] RESNET | separately | SL-VUB  | K=16 --> Acc:  88.24% | Step Time:  3.4s
# [ 71/144 |  49.3%] RESNET | separately | SL-VUB  | K=24 --> Acc:  87.06% | Step Time:  3.0s
# [ 72/144 |  50.0%] RESNET | separately | SL-VUB  | K=32 --> Acc:  86.26% | Step Time:  3.0s
# [ 73/144 |  50.7%] VIT    | jointly    | JG-CLUB | K= 4 --> Acc:  88.67% | Step Time: 33.5s
# [ 74/144 |  51.4%] VIT    | jointly    | JG-CLUB | K= 8 --> Acc:  90.71% | Step Time: 33.9s
# [ 75/144 |  52.1%] VIT    | jointly    | JG-CLUB | K=12 --> Acc:  92.30% | Step Time: 33.0s
# [ 76/144 |  52.8%] VIT    | jointly    | JG-CLUB | K=16 --> Acc:  90.89% | Step Time: 33.8s
# [ 77/144 |  53.5%] VIT    | jointly    | JG-CLUB | K=24 --> Acc:  91.19% | Step Time: 33.9s
# [ 78/144 |  54.2%] VIT    | jointly    | JG-CLUB | K=32 --> Acc:  90.98% | Step Time: 34.1s
# [ 79/144 |  54.9%] VIT    | jointly    | JG-VUB  | K= 4 --> Acc:  91.85% | Step Time: 34.6s
# [ 80/144 |  55.6%] VIT    | jointly    | JG-VUB  | K= 8 --> Acc:  90.64% | Step Time: 33.9s
# [ 81/144 |  56.2%] VIT    | jointly    | JG-VUB  | K=12 --> Acc:  91.88% | Step Time: 32.5s
# [ 82/144 |  56.9%] VIT    | jointly    | JG-VUB  | K=16 --> Acc:  92.39% | Step Time: 33.0s
# [ 83/144 |  57.6%] VIT    | jointly    | JG-VUB  | K=24 --> Acc:  90.75% | Step Time: 33.3s
# [ 84/144 |  58.3%] VIT    | jointly    | JG-VUB  | K=32 --> Acc:  92.27% | Step Time: 32.2s
# [ 85/144 |  59.0%] VIT    | jointly    | SG-CLUB | K= 4 --> Acc:  89.52% | Step Time: 33.4s
# [ 86/144 |  59.7%] VIT    | jointly    | SG-CLUB | K= 8 --> Acc:  89.22% | Step Time: 33.6s
# [ 87/144 |  60.4%] VIT    | jointly    | SG-CLUB | K=12 --> Acc:  89.96% | Step Time: 33.0s
# [ 88/144 |  61.1%] VIT    | jointly    | SG-CLUB | K=16 --> Acc:  89.54% | Step Time: 33.8s
# [ 89/144 |  61.8%] VIT    | jointly    | SG-CLUB | K=24 --> Acc:  83.85% | Step Time: 33.8s
# [ 90/144 |  62.5%] VIT    | jointly    | SG-CLUB | K=32 --> Acc:  86.60% | Step Time: 32.7s
# [ 91/144 |  63.2%] VIT    | jointly    | SG-VUB  | K= 4 --> Acc:  89.59% | Step Time: 33.0s
# [ 92/144 |  63.9%] VIT    | jointly    | SG-VUB  | K= 8 --> Acc:  90.88% | Step Time: 32.5s
# [ 93/144 |  64.6%] VIT    | jointly    | SG-VUB  | K=12 --> Acc:  90.20% | Step Time: 34.3s
# [ 94/144 |  65.3%] VIT    | jointly    | SG-VUB  | K=16 --> Acc:  90.59% | Step Time: 34.6s
# [ 95/144 |  66.0%] VIT    | jointly    | SG-VUB  | K=24 --> Acc:  89.62% | Step Time: 34.7s
# [ 96/144 |  66.7%] VIT    | jointly    | SG-VUB  | K=32 --> Acc:  88.87% | Step Time: 33.8s
# [ 97/144 |  67.4%] VIT    | separately | JG-CLUB | K= 4 --> Acc:  89.43% | Step Time:  3.6s
# [ 98/144 |  68.1%] VIT    | separately | JG-CLUB | K= 8 --> Acc:  90.18% | Step Time:  2.9s
# [ 99/144 |  68.8%] VIT    | separately | JG-CLUB | K=12 --> Acc:  89.76% | Step Time:  3.0s
# [100/144 |  69.4%] VIT    | separately | JG-CLUB | K=16 --> Acc:  89.58% | Step Time:  2.9s
# [101/144 |  70.1%] VIT    | separately | JG-CLUB | K=24 --> Acc:  89.25% | Step Time:  3.5s
# [102/144 |  70.8%] VIT    | separately | JG-CLUB | K=32 --> Acc:  88.88% | Step Time:  3.0s
# [103/144 |  71.5%] VIT    | separately | JG-VUB  | K= 4 --> Acc:  91.35% | Step Time:  2.7s
# [104/144 |  72.2%] VIT    | separately | JG-VUB  | K= 8 --> Acc:  91.79% | Step Time:  2.8s
# [105/144 |  72.9%] VIT    | separately | JG-VUB  | K=12 --> Acc:  91.19% | Step Time:  3.2s
# [106/144 |  73.6%] VIT    | separately | JG-VUB  | K=16 --> Acc:  91.43% | Step Time:  3.1s
# [107/144 |  74.3%] VIT    | separately | JG-VUB  | K=24 --> Acc:  91.58% | Step Time:  2.8s
# [108/144 |  75.0%] VIT    | separately | JG-VUB  | K=32 --> Acc:  91.03% | Step Time:  2.8s
# [109/144 |  75.7%] VIT    | separately | SG-CLUB | K= 4 --> Acc:  87.89% | Step Time:  3.2s
# [110/144 |  76.4%] VIT    | separately | SG-CLUB | K= 8 --> Acc:  87.24% | Step Time:  3.4s
# [111/144 |  77.1%] VIT    | separately | SG-CLUB | K=12 --> Acc:  87.17% | Step Time:  2.9s
# [112/144 |  77.8%] VIT    | separately | SG-CLUB | K=16 --> Acc:  86.33% | Step Time:  3.0s
# [113/144 |  78.5%] VIT    | separately | SG-CLUB | K=24 --> Acc:  85.22% | Step Time:  3.1s
# [114/144 |  79.2%] VIT    | separately | SG-CLUB | K=32 --> Acc:  84.25% | Step Time:  3.4s
# [115/144 |  79.9%] VIT    | separately | SG-VUB  | K= 4 --> Acc:  89.12% | Step Time:  2.8s
# [116/144 |  80.6%] VIT    | separately | SG-VUB  | K= 8 --> Acc:  89.88% | Step Time:  2.8s
# [117/144 |  81.2%] VIT    | separately | SG-VUB  | K=12 --> Acc:  89.45% | Step Time:  3.0s
# [118/144 |  81.9%] VIT    | separately | SG-VUB  | K=16 --> Acc:  89.04% | Step Time:  3.3s
# [119/144 |  82.6%] VIT    | separately | SG-VUB  | K=24 --> Acc:  88.62% | Step Time:  2.8s
# [120/144 |  83.3%] VIT    | separately | SG-VUB  | K=32 --> Acc:  87.81% | Step Time:  2.8s
# [121/144 |  84.0%] VIT    | separately | JL-CLUB | K= 4 --> Acc:  87.19% | Step Time:  3.0s
# [122/144 |  84.7%] VIT    | separately | JL-CLUB | K= 8 --> Acc:  87.25% | Step Time:  3.6s
# [123/144 |  85.4%] VIT    | separately | JL-CLUB | K=12 --> Acc:  86.71% | Step Time:  3.0s
# [124/144 |  86.1%] VIT    | separately | JL-CLUB | K=16 --> Acc:  85.82% | Step Time:  3.0s
# [125/144 |  86.8%] VIT    | separately | JL-CLUB | K=24 --> Acc:  86.09% | Step Time:  3.0s
# [126/144 |  87.5%] VIT    | separately | JL-CLUB | K=32 --> Acc:  85.24% | Step Time:  3.6s
# [127/144 |  88.2%] VIT    | separately | JL-VUB  | K= 4 --> Acc:  90.25% | Step Time:  2.8s
# [128/144 |  88.9%] VIT    | separately | JL-VUB  | K= 8 --> Acc:  90.53% | Step Time:  2.9s
# [129/144 |  89.6%] VIT    | separately | JL-VUB  | K=12 --> Acc:  90.29% | Step Time:  2.9s
# [130/144 |  90.3%] VIT    | separately | JL-VUB  | K=16 --> Acc:  90.10% | Step Time:  3.5s
# [131/144 |  91.0%] VIT    | separately | JL-VUB  | K=24 --> Acc:  89.80% | Step Time:  2.9s
# [132/144 |  91.7%] VIT    | separately | JL-VUB  | K=32 --> Acc:  89.79% | Step Time:  2.9s
# [133/144 |  92.4%] VIT    | separately | SL-CLUB | K= 4 --> Acc:  88.63% | Step Time:  3.2s
# [134/144 |  93.1%] VIT    | separately | SL-CLUB | K= 8 --> Acc:  88.36% | Step Time:  3.8s
# [135/144 |  93.8%] VIT    | separately | SL-CLUB | K=12 --> Acc:  87.95% | Step Time:  3.1s
# [136/144 |  94.4%] VIT    | separately | SL-CLUB | K=16 --> Acc:  87.67% | Step Time:  3.2s
# [137/144 |  95.1%] VIT    | separately | SL-CLUB | K=24 --> Acc:  87.62% | Step Time:  3.3s
# [138/144 |  95.8%] VIT    | separately | SL-CLUB | K=32 --> Acc:  86.84% | Step Time:  3.6s
# [139/144 |  96.5%] VIT    | separately | SL-VUB  | K= 4 --> Acc:  89.80% | Step Time:  3.1s
# [140/144 |  97.2%] VIT    | separately | SL-VUB  | K= 8 --> Acc:  90.72% | Step Time:  3.1s
# [141/144 |  97.9%] VIT    | separately | SL-VUB  | K=12 --> Acc:  90.06% | Step Time:  3.4s
# [142/144 |  98.6%] VIT    | separately | SL-VUB  | K=16 --> Acc:  90.67% | Step Time:  3.4s
# [143/144 |  99.3%] VIT    | separately | SL-VUB  | K=24 --> Acc:  90.02% | Step Time:  3.1s
# [144/144 | 100.0%] VIT    | separately | SL-VUB  | K=32 --> Acc:  89.57% | Step Time:  3.1s
#
# --> Saving figures and metrics to: ./results
# --> Done! Full benchmark finished in 33.0 minutes.
#     - PNG:  ./results/rate_accuracy_clean_2x2.png
#     - PDF:  ./results/rate_accuracy_clean_2x2.pdf
#     - JSON: ./results/benchmark_clean_metrics.json
